# %% [markdown]
# # A first look at a neural network

# %% [markdown]
# ## Loading the MNIST dataset from Keras

# %%
from tensorflow.keras.datasets import mnist
(train_images, train_labels), (test_images, test_labels) = mnist.load_data()
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/mnist.npz
# 11490434/11490434 [==============================] - 0s 0us/step

# %%
train_images.shape
# Out:
# (60000, 28, 28)

# %%
len(train_labels)
# Out:
# 60000

# %%
train_labels
# Out:
# array([5, 0, 4, ..., 5, 6, 8], dtype=uint8)

# %%
test_images.shape
# Out:
# (10000, 28, 28)

# %%
len(test_labels)
# Out:
# 10000

# %%
test_labels
# Out:
# array([7, 2, 1, ..., 4, 5, 6], dtype=uint8)

# %% [markdown]
# ## The network architecture

# %%
from tensorflow import keras
from tensorflow.keras import layers
model = keras.Sequential([
    layers.Dense(512, activation="relu"),
    layers.Dense(10, activation="softmax")
])

# %% [markdown]
# ## The compilation step

# %%
model.compile(optimizer="rmsprop",
              loss="sparse_categorical_crossentropy",
              metrics=["accuracy"])

# %% [markdown]
# ## Preparing the image data

# %%
train_images = train_images.reshape((60000, 28*28))
# train_images = train_images.astype("float32") / 255
test_images = test_images.reshape((10000, 28*28))
# test_images = test_images.astype("float32") / 255

# %% [markdown]
# ## "Fitting" the model

# %%
model.fit(train_images, train_labels, epochs=5, batch_size=128)
# Out:
# Epoch 1/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0288 - accuracy: 0.9915
# Epoch 2/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0219 - accuracy: 0.9937
# Epoch 3/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0169 - accuracy: 0.9952
# Epoch 4/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0127 - accuracy: 0.9967
# Epoch 5/5
# 469/469 [==============================] - 1s 3ms/step - loss: 0.0097 - accuracy: 0.9975

# %% [markdown]
# ## Using the model to make predictions

# %%
test_digits = test_images[0:10]
predictions = model.predict(test_digits)
predictions[0]
# Out:
# 1/1 [==============================] - 0s 87ms/step
# array([2.0934765e-10, 1.1124850e-12, 6.1899549e-08, 1.2141353e-06,
#        2.7302590e-16, 2.3643845e-12, 8.8179243e-16, 9.9999869e-01,
#        4.6906944e-11, 2.9726519e-09], dtype=float32)

# %%
predictions[0].argmax()
# Out:
# 7

# %%
predictions[0][7]
# Out:
# 0.9999987

# %%
test_labels[0]
# Out:
# 7

# %% [markdown]
# ## Evaluating the model on new data

# %%
test_loss, test_acc = model.evaluate(test_images, test_labels)
print(f"test_acc: {test_acc}")
# Out:
# 313/313 [==============================] - 2s 6ms/step - loss: 0.0757 - accuracy: 0.9789
# test_acc: 0.9789000153541565
